# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-40e00e36-34d0-4960-89a6-38e086dc77de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40e00e36-34d0-4960-89a6-38e086dc77de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ejemplo.csv to ejemplo.csv
# User uploaded file "ejemplo.csv" with length 22 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('example_semTec.txt', 'w') as f:
  f.write('ejemplo clase sem tec')

files.download('example_semTec.txt')

# %%
ls
# Out:
# ejemplo.csv  example_semTec.txt  sample_data/

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/TecSem2/SemanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive//TecSem2/SemanaTec/foo.txt
# Out:
# Hello Google Drive!

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: TecSem2, id: 14bhEV1rpHY437IcDeF0XKJZ6lSXVmjq6
# title: Actividad 1: Manejo de consola, id: 13XSWmrnoKE-CgG5iSDIdm1W1fwzZXJS-gRVOqCbDhFQ
# title: Presentación sin título, id: 1O3Dfq9WeXC50g-r_D9Mxi_a5Ogwu7WW4znzAbFPDfSk
# title: Flujo 2.MOV, id: 1usM7hU2nMfivgJg843RYD5NHzS0HlnHT
# title: Flujo 1.MOV, id: 10s6ibBUldUKdtuo8wJi0SA0MixVLQHhp
# title: Ecological Footprint phase 2, id: 1tAD56s2ntHsq6BhYZdRKSRRHp8u6zt2A2zAbuwdl5Jc
# title: even the rain, id: 14ekgynb-C0sauSOmn2aTn8DyPrZy72Tq5-o7qcdcJF0
# title: ecological Footprint-Team 1, id: 1Gl1KDKUzGDHz-h9CJ4yDU34BRMsuXRr9fFNIN1h3o_E
# title: Actividad 1:fisica, id: 1IsQ-UKThFe7mvoSEXDF9GfzKq0ZyVjVBmRd8OvVcjSQ
# title: Ejercicios Mate, id: 1k4S-A4U_xdTnZMCTsV1Ca0z15jtG4yy7mysyYR44-ww
# title: Ensayo integracion, id: 1h7Lum5Wxx607MdiKBCz408eF_p5UdgmpcvAiPvfwR98
# title: videos, id: 1hA7WCH1R5KXqS6hAoEmhQVvZkE6pXcKA
# title: Autocuidado_video.mov, id: 1LkfQhv5KlnEbpqtE-hKKCFuVK0Onq6tl
# title: reto_caso_alterno.m, id: 1PbJBHvD4tqOigXY0tT1HxUkCAsCWg_pr
# title: Fase 1. Piñón-Cremallera, id: 1Ycs1m_Jlwu8oqZuARwNgIkgxl_Y7x74meox1rAnknwQ
# title: reto_angulo.m, id: 1NU_6dJo2aqoJWpZ3M9lrJDEdDk1LL95M
# title: Examen Modulos Física, id: 18wRTRMUj0PxcERt6lGxZtI4Zb0r9fLDFuvmCQ9KSoK0
# title: reto_og.m, id: 1kiieQv14U54iqYsf72XKU9JoJ1qWf_P6
# title: reto_fuerza_t.m, id: 1Ry_Z_lNFHzf5N2povqEuPcckv_jCbm1t
# title: reto movimiento, id: 1Ko7EiA7C1eWz6b9ZiMNBcvB8P4rR-dikNABj-DGXfzw
# title: Environmental Hysteria, id: 1fX_raxU2BsXeoJlZTfs2dVJj4o2WSIdqUAc4-SmnJqE
# title: Actividad 2, id: 1eVJmQTtk9advbDY1pQEtaKwwUippmemFuMLUAmq5PuQ
# title: actividad _individual_reto, id: 1U86TDMhRXYkRiP57o6xInXYXQpBfYZc4uEqncNckOns
# title: Actividad Mate, id: 118mPsP3UCE9LyqdBW2q_0AjryGTJhsSevHjaDg_5GjM
# title: Actividad 1, id: 1Rn8Nk8fZvkYSGxlQzHsPCNrJyCfQRMSPX272I07xD30
# title: Phase 2. Network mapping, id: 1txwZgaiCX7IyY9HDBK9fy7PCs--dL4wTsg6wAcCL1_Y
# title: Phase 2, id: 1Yf3LnezGEoiS5fHdTv3a_s_thFlGzcmyXtj--5vPL_E
# title: A01028579_casos, id: 1ArD8UKodt8khwxwAVcVt_DplvJrir0CeutXcyzSb3xA
# title: equipo1_detección_de_bordes, id: 1yAqteZR7hfRRp4fwFyvpADhsoHV63CpD-WE4dCEY86s
# title: A01028579_evidencia02, id: 13ZW7ro21a8TW6Bb_bB7Vw7gh9uSsaSrP_OgJtajD1e0
# title: IMG_1398.mov, id: 183ZCnPNgMLQXzLzXdK-FoxTOz-hXI-EP
# title: Image segmentation, id: 1dgAzJDDkFK-gB2_VhAofjkfX6kZQmPxtTZSMFsSNofw
# title: A01028579_inducción, id: 1GQCX9VD3m-OIpV_cX6V8svZxcZRdXMMo-rvoyFrDVq8
# title: Arbol, id: 1VJIosWWPZwi-BiBNvt7izQIjSlLFpfOJU4lHz-tUAcw
# title: Reto actividad 2, id: 1yeS2wcyBazkfx1JA1HueigVNAKVaNcvRcau6lUuqBac
# title: Tec semestre 1, id: 1HGb0ZmykQkhDPHHFeoGp11QjgwPDI-CH

# %%
fid= '14bhEV1rpHY437IcDeF0XKJZ6lSXVmjq6'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1a_4d30-uE1aTjR5aO6vaMC4dvvZ2drW0

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1a_4d30-uE1aTjR5aO6vaMC4dvvZ2drW0'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('myCoolSpreadsheet')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('myCoolSpreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1mioSnZ69d-zCgm3aIqDnxaHipKksYD2rKSJvcZa_4Rs',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('myCoolSpreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['2', '4', '9'], ['5', '1', '2']]
# ******************Data Frame*********************
#    0  1  2
# 0  2  4  9
# 1  5  1  2
